# %% [markdown]
# # SHANTHINI M K - GRIPAUGUST21
#  COMPUTER VISION AND IOT - **TASK1- OBJECT DETECTION OR OPTICAL CHARACTER RECOGNITION (ORC)**

# %% [markdown]
# #IMPORT LIBRARIES

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# #Install Pytesseract and tesseract-OCR in Google Colab.

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 40 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 2s (3,022 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %% [markdown]
# #Import libraries

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %% [markdown]
# #Upload Image to the Colab

# %%
image = cv.imread("/content/imag.jpg")
plt.imshow(image)

# %% [markdown]
# #Convert image to grayscale

# %%
gray = cv.cvtColor(image,cv.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# #Text Extraction

# %%
text = pytesseract.image_to_string(gray)
text
# Out:
# '“THE HAPPINESS\n‘OF YOUR LIFE\nDEPENDS ON THE QUALITY\n‘OF Your THOUGHTS.\n\nago\n\n \n\x0c'
